# %% [markdown]
# # Assignment 2: Environment Package Versions
#
# This notebook displays the Python version and all installed package versions for the `testenv` conda environment.

# %% [markdown]
# ## Python Version

# %%
import sys

print("Python version:")
print(sys.version)
# Out:
# Python version:
# 3.9.25 (main, Nov  3 2025, 22:44:01) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ## Package Versions

# %%
import jupyterlab
print(f"jupyterlab: {jupyterlab.__version__}")
# Out:
# jupyterlab: 4.4.7

# %%
import pandas
print(f"pandas: {pandas.__version__}")
# Out:
# pandas: 2.3.3

# %%
import pandas_datareader
print(f"pandas_datareader: {pandas_datareader.__version__}")
# Out:
# pandas_datareader: 0.10.0

# %%
import numpy
print(f"numpy: {numpy.__version__}")
# Out:
# numpy: 2.0.2

# %%
import matplotlib
print(f"matplotlib: {matplotlib.__version__}")
# Out:
# matplotlib: 3.9.2

# %%
import sklearn
print(f"sklearn: {sklearn.__version__}")
# Out:
# sklearn: 1.6.1

# %%
import django
print(f"django: {django.__version__}")
# Out:
# django: 4.1

# %%
import tensorflow
print(f"tensorflow: {tensorflow.__version__}")
# Out:
# tensorflow: 2.20.0

# %%
import scipy
print(f"scipy: {scipy.__version__}")
# Out:
# scipy: 1.13.1

# %%
import keras
print(f"keras: {keras.__version__}")
# Out:
# keras: 3.10.0

# %%
import seaborn
print(f"seaborn: {seaborn.__version__}")
# Out:
# seaborn: 0.13.2

# %%
import cv2
print(f"cv2 (opencv-python): {cv2.__version__}")
# Out:
# cv2 (opencv-python): 4.13.0

# %%
import nltk
print(f"nltk: {nltk.__version__}")
# Out:
# nltk: 3.9.2

# %%
import statsmodels
print(f"statsmodels: {statsmodels.__version__}")
# Out:
# statsmodels: 0.14.5
