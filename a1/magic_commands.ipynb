# %% [markdown]
# # Magic Commands

# %%
# https://www.aboutdatablog.com/post/top-8-magic-commands-in-jupyter-notebook
# https://ipython.readthedocs.io/en/stable/interactive/magics.html

# Magic Commands:
# Special commands that help with running and analyzing data in Jupyter notebooks.
# Single % for one line of code, or double %% for several lines of code.

# %% [markdown]
# ## 1. List all magic commands: %lsmagic

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# example line magic
# %ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is C669-21DD
#
#  Directory of D:\Users\theon\OneDrive - Florida State University\lis4376\a1
#
# 01/18/2026  03:15 PM    <DIR>          .
# 01/18/2026  03:15 PM    <DIR>          ..
# 01/18/2026  03:10 PM    <DIR>          .ipynb_checkpoints
# 01/17/2026  07:24 PM    <DIR>          .virtual_documents
# 01/17/2026  06:51 PM             3,400 a1_paycheck_calculator.ipynb
# 01/13/2026  03:32 PM             1,273 a1_paycheck_calculator.py
# 01/17/2026  05:01 PM    <DIR>          anaconda_projects
# 01/13/2026  04:05 PM                19 demo.py
# 01/13/2026  04:05 PM                22 hello.py
# 01/17/2026  12:45 PM    <DIR>          img
# 01/18/2026  03:15 PM            10,186 magic_commands.ipynb
# 01/15/2026  02:25 PM             2,304 README.md
# 01/18/2026  01:54 PM             4,367 run_py_files_in_jupyter_lab.ipynb
# 01/18/2026  01:49 PM                43 test.py
#                8 File(s)         21,614 bytes
#                6 Dir(s)  233,367,105,536 bytes free

# %% [markdown]
# ## 2. Run file: %run

# %%
# example run file
# %run hello.py
# Out:
# Hello, world

# %% [markdown]
# ## 3. Load file: %load
#
# **Note:** %run runs file; %load loads file into cell

# %%
# %load hello.py
# Note: File was loaded into cell, then cell code was modified!

# print('Hello, world')

# or, create function
def hello_test():
    print('Hello, test!')

hello_test()
# Out:
# Hello, test!

# %% [markdown]
# ## 4. Return execution time: %%time
#
# **Note:** %%time is 'cell magic' and **must be** first line in Jupyter notebook cell.

# %%
# %%time
import random
for i in range(0, 1000000):
    random.random()

# display time to generate 1,000,000 random numbers
# Note: Placing these comments above code generates an error!
# Out:
# CPU times: total: 62.5 ms
# Wall time: 102 ms

# %% [markdown]
# ## 5. List all variables: %who

# %%
# example
my_var1 = 1
my_var2 = 'hello'
my_var3 = True

# %%
# List all variables
# %who
# Out:
# NamespaceMagics	 collections	 dataframe_columns	 dataframe_hash	 dtypes_str	 get_dataframes	 get_ipython	 getpass	 hashlib
# hello_test	 i	 import_pandas_safely	 is_data_frame	 islice	 json	 my_var1	 my_var2	 my_var3
# random	 sys

# %%
# List specific variable
# %who bool
# Out:
# my_var3

# %% [markdown]
# ## 6. Display variable details: %pinfo

# %%
# example (note: includes length of string)
# %pinfo my_var2
# Out:
# Type:        str
# String form: hello
# Length:      5
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to 'utf-8'.
# errors defaults to 'strict'.

# %% [markdown]
# ## 7. Get/set environmental variables: %env

# %%
# example: list environmental variables
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\theon\\AppData\\Roaming',
#  'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey',
#  'CHOCOLATEYLASTPATHUPDATE': '133936889969956374',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'DESKTOP-QHRPCLR',
#  'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#  'CONDA_DEFAULT_ENV': 'base',
#  'CONDA_EXE': 'D:\\ProgramData\\anaconda3\\Scripts\\conda.exe',
#  'CONDA_PREFIX': 'D:\\ProgramData\\anaconda3',
#  'CONDA_PROMPT_MODIFIER': '(base) ',
#  'CONDA_PYTHON_EXE': 'D:\\ProgramData\\anaconda3\\python.exe',
#  'CONDA_SHLVL': '1',
#  'DOTNET_ROOT': 'C:\\Users\\theon\\AppData\\Local\\Microsoft\\dotnet',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\theon',
#  'IPY_INTERRUPT_EVENT': '2952',
#  'JPY_INTERRUPT_EVENT': '2952',
#  'JPY_PARENT_PID': '2684',
#  'JPY_SESSION_NAME': 'D:\\Users\\theon\\OneDrive - Florida State University\\lis4376\\a1\\magic_commands.ipynb',
#  'LOCALAPPDATA': 'C:\\Users\\theon\\AppData\\Local',
#  'LOGONSERVER': '\\\\DESKTOP-QHRPCLR',
#  'NUMBER_OF_PROCESSORS': '6',
#  'NVM_HOME': 'D:\\Users\\theon\\AppData\\Local\\nvm',
#  'NVM_SYMLINK': 'C:\\nvm4w\\nodejs',
#  'ONEDRIVE': 'D:\\Users\\theon\\OneDrive - Florida State University',
#  'ONEDRIVECOMMERCIAL': 'D:\\Users\\theon\\OneDrive - Florida State University',
#  'OS': 'Windows_NT',
#  'PATH': 'D:\\ProgramData\\anaconda3;D:\\ProgramData\\anaconda3\\Library\\mingw-w64\\bin;D:\\ProgramData\\anaconda3\\Library\\usr\\bin;D:\\ProgramData\\anaconda3\\Library\\bin;D:\\ProgramData\\anaconda3\\Scripts;D:\\ProgramData\\anaconda3\\bin;D:\\ProgramData\\anaconda3\\condabin;C:\\Python313\\Scripts;C:\\Python313;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0;C:\\Windows\\System32\\OpenSSH;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\Program Files\\dotnet;C:\\Program Files (x86)\\cloudflared;C:\\ProgramData\\chocolatey\\bin;D:\\Users\\theon\\AppData\\Local\\nvm;C:\\nvm4w\\nodejs;C:\\Program Files\\NVIDIA Corporation\\NVIDIA App\\NvDLISR;C:\\Program Files\\Git\\cmd;C:\\Program Files\\cursor\\resources\\app\\bin;C:\\Program Files\\GitHub CLI;C:\\Users\\theon\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\theon\\AppData\\Roaming\\npm;D:\\Users\\theon\\AppData\\Local\\nvm;C:\\nvm4w\\nodejs;C:\\Users\\theon\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\theon\\AppData\\Local\\Microsoft\\dotnet;C:\\Users\\theon\\AppData\\Local\\Programs\\Antigravity\\bin',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC;.PY;.PYW',
#  'PROCESSOR_ARCHITECTURE': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 158 Stepping 12, GenuineIntel',
#  'PROCESSOR_LEVEL': '6',
#  'PROCESSOR_REVISION': '9e0c',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program Files',
#  'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#  'PROGRAMW6432': 'C:\\Program Files',
#  'PROMPT': '(base) $P$G',
#  'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#  'PT8HOME': 'D:\\Program Files\\Cisco Packet Tracer 9.0.0',
#  'PUBLIC': 'C:\\Users\\Public',
#  'SESSIONNAME': 'Console',
#  'SSL_CERT_FILE': 'D:\\ProgramData\\anaconda3\\Library\\ssl\\cacert.pem',
#  'SUBPROCESS_BAGGAGE': 'sentry-trace_id=890c031cfcbe4b0c85a844b36ed6a88d,sentry-environment=local_production,sentry-release=4.20.0,sentry-public_key=f175bff95ca4ae57c532f2bf67cbaa63',
#  'SUBPROCESS_SENTRY_TRACE': '890c031cfcbe4b0c85a844b36ed6a88d-bcacf0d386578b98',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\Windows',
#  'TEMP': 'C:\\Users\\theon\\AppData\\Local\\Temp',
#  'TMP': 'C:\\Users\\theon\\AppData\\Local\\Temp',
#  'USERDOMAIN': 'DESKTOP-QHRPCLR',
#  'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-QHRPCLR',
#  'USERNAME': 'theon',
#  'USERPROFILE': 'C:\\Users\\theon',
#  'WINDIR': 'C:\\Windows',
#  '__CONDA_OPENSLL_CERT_FILE_SET': '"1"',
#  '__PSLOCKDOWNPOLICY': '0',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'FORCE_COLOR': '1',
#  'CLICOLOR_FORCE': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
# add new environmental variable called MY_VAR:
# %env MY_VAR=Users/someuser
# Out:
# env: MY_VAR=Users/someuser

# %%
# check specific environment variable value
# %env JAVA_HOME
# Out:
# UsageError: Environment does not have key: JAVA_HOME
